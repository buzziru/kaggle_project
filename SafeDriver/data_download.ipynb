# %%
# !chmod 600 ../.kaggle/kaggle.json

# %%
# !kaggle competitions download -c porto-seguro-safe-driver-prediction -p ./data
# Out:
# ...
#   0%|                                               | 0.00/76.5M [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 76.5M/76.5M [00:00<00:00, 1.08GB/s]

# %%
# !unzip -o ./data/porto-seguro-safe-driver-prediction.zip -d ./data
# !rm ./data/porto-seguro-safe-driver-prediction.zip
# Out:
# Archive:  ./data/porto-seguro-safe-driver-prediction.zip
#   inflating: ./data/sample_submission.csv
#   inflating: ./data/test.csv
#   inflating: ./data/train.csv
