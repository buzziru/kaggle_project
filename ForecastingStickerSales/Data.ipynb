# %%
# !kaggle competitions download -c playground-series-s5e1 -p './data'
# Out:
# ...
#   0%|                                               | 0.00/2.26M [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 2.26M/2.26M [00:00<00:00, 124MB/s]

# %%
import os
import zipfile

# %%
cur_dir = os.getcwd()
cur_dir
# Out:
# '/teamspace/studios/this_studio/ForecastingStickerSales'

# %%
zip_path = os.path.join(cur_dir, 'data', 'playground-series-s5e1.zip')
extract_path = os.path.join(cur_dir, 'data')

with zipfile.ZipFile(zip_path, 'r') as f:
    f.extractall(extract_path)

os.remove(zip_path)
