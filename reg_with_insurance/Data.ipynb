# %%
import os
import zipfile

# %%
cur_dir = os.getcwd()
cur_dir
# Out:
# '/teamspace/studios/this_studio/reg_with_insurance'

# %%
zip_path = os.path.join(cur_dir, 'data', 'playground-series-s4e12.zip')
extract_path = os.path.join(cur_dir, 'data')

with zipfile.ZipFile(zip_path, 'r') as f:
    f.extractall(extract_path)

os.remove(zip_path)
