# %%
# !chmod 600 ../.kaggle/kaggle.json

# %%
# !kaggle competitions download -c cat-in-the-dat -p ./data
# Out:
# ...
#   0%|                                               | 0.00/21.2M [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 21.2M/21.2M [00:00<00:00, 874MB/s]

# %%
# !unzip -o ./data/cat-in-the-dat.zip -d ./data
# !rm ./data/cat-in-the-dat.zip
# Out:
# Archive:  ./data/cat-in-the-dat.zip
#   inflating: ./data/sample_submission.csv
#   inflating: ./data/test.csv
#   inflating: ./data/train.csv
