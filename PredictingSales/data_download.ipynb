# %%
# !chmod 600 ../.kaggle/kaggle.json

# %%
# !kaggle competitions download -c competitive-data-science-predict-future-sales -p ./data
# Out:
# ...
#   0%|                                               | 0.00/15.1M [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 15.1M/15.1M [00:00<00:00, 917MB/s]

# %%
# !unzip -o ./data/competitive-data-science-predict-future-sales.zip -d ./data
# !rm ./data/competitive-data-science-predict-future-sales.zip
# Out:
# Archive:  ./data/competitive-data-science-predict-future-sales.zip
#   inflating: ./data/item_categories.csv
#   inflating: ./data/items.csv
#   inflating: ./data/sales_train.csv
#   inflating: ./data/sample_submission.csv
#   inflating: ./data/shops.csv
#   inflating: ./data/test.csv
